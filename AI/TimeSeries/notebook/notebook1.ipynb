# %%
# Out:
# The kernel failed to start as 'TypeAliasType' could not be imported from 'c:\Users\Tejas\anaconda\envs\tfenv\lib\site-packages\typing_extensions.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
# Out:
# The kernel failed to start as 'TypeAliasType' could not be imported from 'c:\Users\Tejas\anaconda\envs\tfenv\lib\site-packages\typing_extensions.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
